# %%
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\SHRUTI S\Documents\Repos\Entab Internship\Data Analysis\June 2024.xlsx")

# %%
data.head()
# Out:
#    Ticket ID                                            Subject  \
# 0     991741  Registration || (Std. X) Email Format || Vince...
# 1     991742  Fwd: fee payment clarification for Siya gupta ...
# 2     991743  Reconciliation (from 01/04/2024 to 16/05/2024)...
# 3     991744                           Fee details not uploaded
# 4     991745  Fwd: Double payment for the quarter March 2024...
#
#                                          Description  Status Priority  \
# 0                                                NaN  Closed     High
# 1  Adding others. Thanks, Sourabh ---------- Forw...  Closed     High
# 2  Reconciliation (from 01/04/2024 to 16/05/2024)...  Closed      Low
# 3  Hi Team, My Daughter Navanya D is moving to LK...  Closed     High
# 4  ---------- Forwarded message --------- From: D...  Closed      Low
#
#      Source            Type                            Agent          Group  \
# 0  Internal  Change Request                  Shivam Bhardwaj      PD- Manju
# 1     Email           Query                      Pooja Yadav            PHD
# 2     Phone  Proactive Task                     Vani Poudwal        Elite_2
# 3     Email           Query                      Pooja Yadav            PHD
# 4     Email  Change Request  PreetiNegi/Entab- Tech. Support  Innovators_1A
#
#           Created time  ... Happiness Index Weightage  \
# 0  2024-05-26 09:06:59  ...             NaN       1.0
# 1  2024-05-26 10:59:36  ...             NaN       NaN
# 2  2024-05-26 11:02:28  ...             NaN       NaN
# 3  2024-05-26 17:48:42  ...             NaN       NaN
# 4  2024-05-26 19:13:02  ...             NaN       NaN
#
#                      Module             Full name  \
# 0  Registration & Admission          1726#Elite_2
# 1       Student Information         Sourabh Gupta
# 2           Fee and Billing   Mr. Bhupesh Jaiswal
# 3           Fee and Billing          Dinesh Dilli
# 4           Fee and Billing  Mrs. Smruti Kulkarni
#
#                               Email File No.  \
# 0               1726entab@dummy.com   1726.0
# 1               sourabh44@gmail.com      NaN
# 2             bhupesh@tagoreint.com    111.0
# 3             ddineshnani@gmail.com      NaN
# 4  powai.accounts@bombayscottish.in    562.0
#
#                                         Company Name        Support  \
# 0  1726#St. Vincent Pallotti School, Bengaluru, K...        Elite_2
# 1                                                NaN            NaN
# 2  111#Tagore International School, Vasant Vihar,...        Elite_2
# 3                                                NaN            NaN
# 4     562#Bombay Scottish School, Powai, Maharashtra  Innovators_1A
#
#         Segment  Product Type
# 0       Elite_2           MVC
# 1           NaN           NaN
# 2       Elite_2           MVC
# 3           NaN           NaN
# 4  Innovators_1           MVC
#
# [5 rows x 42 columns]

# %%
data.shape
# Out:
# (22708, 42)

# %%
Data_forprocessing = data[['Ticket ID', 'Description', 'Module']].copy()
Data_forprocessing.dropna(subset=['Description', 'Module'], inplace = True)
Data_forprocessing.shape
# Out:
# (22253, 3)

# %%
from openpyxl import Workbook

# Path to existing Excel file
file_path = r"C:\Users\SHRUTI S\Documents\Repos\Entab Internship\Data Analysis\June 2024.xlsx"

# Path to new Excel file
output_file_path = r"C:\Users\SHRUTI S\Documents\Repos\Entab Internship\Data Analysis\JuneDataWithKeywords.xlsx"

# Load data from Excel
data = pd.read_excel(file_path, sheet_name="Data")

# Define keywords
keywords = [
    'Updation', 'Assignment', 'Assigner', 'Reconciliation', 'module wise status',
    'Online Payment', 'Update', 'Paid', 'Promotion', 'Mark assigner', 'Design',
    'SMS', 'DLT', 'Training', 'DEMO', 'Concession', 'Fixed', 'Route Assigner',
    'Demote', 'Chargeback', 'Permission', 'Create', 'Preupgradation', 'Pre Upgradation',
    'Pre-upgradation', 'Upload', 'Entry', 'Fee structure', 'Fine Setting', 'Transfer',
    'Settings', 'Setting', 'collection', 'Adjustment', 'Creation', 'Create',
    'optional subject', 'optional', 'Modification', 'Fee Group', 'Assigning',
    'Tally', 'Tallied', 'visit', 'Data updation', 'Membership', 'Book Entry',
    'Bulk', 'Delete', 'Mapping'
]

# Initialize an empty list to store rows
rows = []

# Initialize an empty DataFrame for keywords (optional)
keywords_df = pd.DataFrame(columns=['Ticket ID', 'Subject', 'Description', 'Module'] + keywords)

# Create a new workbook
book = Workbook()

# Remove the default sheet created by openpyxl
book.remove(book.active)

# Create a sheet for writing the data
sheet = book.create_sheet('KeywordResults')

# Write headers
sheet.append(['Ticket ID', 'Subject', 'Description', 'Module'] + keywords)

# Write data
for idx, row in data.iterrows():
    token_id = row['Ticket ID']
    subject = row['Subject']
    description = str(row['Description'])
    module = row.get('Module', '')  # Get 'Module' column value or default to empty string if not present
    token_row = {'Ticket ID': token_id, 'Subject': subject, 'Description': description, 'Module': module}
    
    # Check for presence of keywords in description (case insensitive) and assign values
    for keyword in keywords:
        if keyword.lower() in description.lower():
            token_row[keyword] = 1
        else:
            token_row[keyword] = 0
    
    # Append current row to list of rows
    rows.append(token_row)

# Write data to the sheet
for row in rows:
    row_data = [row['Ticket ID'], row['Subject'], row['Description'], row['Module']] + [row[keyword] for keyword in keywords]
    sheet.append(row_data)

# Save workbook
book.save(output_file_path)

print(f"Keywords data has been successfully written to '{output_file_path}'")
# Out:
# Keywords data has been successfully written to 'C:\Users\SHRUTI S\Documents\Repos\Entab Internship\Data Analysis\JuneDataWithKeywords.xlsx'
